# %%
import pandas as pd
import glob
import os
from os.path import abspath

# %%
'''Retrieve and read last stored csv file'''
data_path = abspath('./data/')
lst = os.listdir(data_path)
lst.sort(reverse=True)

dir = lst[0]
dir_path = data_path + '/' + dir 
file_path = glob.glob(dir_path + '/*')[0]

df = pd.read_csv(file_path)
df.sort_values(by='ranking')
# Out:
#        IMBd_id                         title  ranking ranking_name  \
# 100  tt0111161      The Shawshank Redemption        1      top_250
# 101  tt0068646                 The Godfather        2      top_250
# 102  tt0468569               The Dark Knight        3      top_250
# 103  tt0071562        The Godfather: Part II        4      top_250
# 104  tt0050083                  12 Angry Men        5      top_250
# ..         ...                           ...      ...          ...
# 45   tt0031679  Mr. Smith Goes to Washington      246      top_250
# 46   tt0031381            Gone with the Wind      247      top_250
# 47   tt0025316         It Happened One Night      248      top_250
# 48   tt0019254    The Passion of Joan of Arc      249      top_250
# 49   tt0017925                   The General      250      top_250
#
#     released_year duration_min                    genre  \
# 100          1994       142min                    Drama
# 101          1972       175min              Crime,Drama
# 102          2008       152min       Action,Crime,Drama
# 103          1974       202min              Crime,Drama
# 104          1957        96min              Crime,Drama
# ..            ...          ...                      ...
# 45           1939       129min             Comedy,Drama
# 46           1939       238min    Drama,History,Romance
# 47           1934       105min           Comedy,Romance
# 48           1928       114min  Biography,Drama,History
# 49           1926        67min  Action,Adventure,Comedy
#
#                    collected_at
# 100  2021-11-02 13:41:29.925563
# 101  2021-11-02 13:41:29.926465
# 102  2021-11-02 13:41:29.927330
# 103  2021-11-02 13:41:29.928202
# 104  2021-11-02 13:41:29.929340
# ..                          ...
# 45   2021-11-02 13:41:34.191170
# 46   2021-11-02 13:41:34.192053
# 47   2021-11-02 13:41:34.192976
# 48   2021-11-02 13:41:34.193818
# 49   2021-11-02 13:41:34.194852
#
# [250 rows x 8 columns]
